# %% [markdown]
# ### 正规方程使用

# %%
import numpy as np

# %%
X = np.array([[1,1],[2,-1]])
X
# Out:
# array([[ 1,  1],
#        [ 2, -1]])

# %%
y = np.array([14, 10])
y
# Out:
# array([14, 10])

# %%
# linalg 线性代数，slove计算先行回归问题
np.linalg.solve(x,y)
# Out:
# array([8., 6.])

# %% [markdown]
# $$ f(x,y)=8x +6y

# %% [markdown]
# $$ W = (X^TX)^{-1}X^Ty

# %%
# X转制
X.T
# 矩阵运算
A = X.T.dot(X)
# 逆矩阵计算
B = np.linalg.inv(A)
C = B.dot(X.T)
C.dot(y)
# Out:
# array([8., 6.])

# %% [markdown]
# #### 三元一次方程

# %%
X = np.array([[1, -1, 1], [2, 1, -1], [3, -2, 6]])
X
# Out:
# array([[ 1, -1,  1],
#        [ 2,  1, -1],
#        [ 3, -2,  6]])

# %%
y = np.array([100, 80, 256])
y
# Out:
# array([100,  80, 256])

# %%
np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)
# Out:
# array([ 60., -41.,  -1.])

# %% [markdown]
# ### sklearn算法使用

# %%
# linear线性，model模型、算法
# LinearRegression：线性回归
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression(fit_intercept=False)
# fit_intercept=False不计算截距

# X 数据； y 目标值
display(X,y)
model.fit(X,y)
# coef_ 结果，返回值，斜率，系数，方程的解
model.coef_
# Out:
# array([[ 1, -1,  1],
#        [ 2,  1, -1],
#        [ 3, -2,  6]])
# array([100,  80, 256])
# array([ 60., -41.,  -1.])

# %% [markdown]
# ### 带截距的线性方程

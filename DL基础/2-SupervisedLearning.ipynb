# %% [markdown]
# # Supervised Learning
#
# refers to algorithms that learn x to y input to output mappings.
#
# Key: Learns from being given **"right answers"**
#
# ## Regression: Housing Price Prediction
#
# Predict a **number**
#
# **infinitely** many possible outputs
#
# ![image.png](images/image.png)

# %% [markdown]
# ## Classification: Brest Camcer detection
#
# 0: Benign(良性)
#
# 1: Malignant(恶性)
#
# ![image.png](images/image%20copy.png)
#
# If a new patient comes in for diagnosis and they have a mass this large, the question is, will your system classify this tumor as benign or malignant?
#
# Predict **categories**
#
# **small number** of possible outputs
#
#
# ![image.png](images/image%20copy%202.png)

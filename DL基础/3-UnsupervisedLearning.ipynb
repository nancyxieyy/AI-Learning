# %% [markdown]
# # Unsupervised Learning
#
# Data only comes with inputs x, but not outputs labels y
#
# Algorithms had to find **structure** in the data
#
# Find something interesting
#
# in **unlabeled** data
#
# ## Clustering: Grouping customers
#
# Group similar data points together
#
# ![image.png](images/image%20copy%203.png)

# %% [markdown]
# Question
#
# Of the following examples, which would you address using an Unsupervised Learning algorithm?
#
# - Given email labeled ad spam/not spam, learn a spam filter.
# - Given a set of news articles found on the web, group them into sets of articles about the same story.✅
# - Given a database of customer data, automatically discover market segments and group customers into different market segments.✅
# - Given a dataset of patients diagnosed as either having diabetes or not, learn to classify new patients as having diabetes or not.

# %% [markdown]
# ## Anomaly Detection(异常检测)
#
# Find unusual data points

# %% [markdown]
# ## Dimensionality reduction(降维)
#
# Compress data using fewer numbers

# %% [markdown]
# 1. 主厨额百度千帆账号：
# https://login.bce.baidu.com/?redirect=https%3A%2F%2Fconsole.bce.baidu.com%2Fqianfan%2Fais%2Fconsole%2FapplicationConsole%2Fapplication
#
# 2. 创建千帆应用，获取`AppID`、`API Key`、`Secret Key`等信息

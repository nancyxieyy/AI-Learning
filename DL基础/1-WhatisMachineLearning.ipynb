# %% [markdown]
# Question
#
# If the checkers program had been allowed to play only ten games(instead of tens of thousands) against itself, a much smaller number of games, how would the have affected its performance?
#
# Answer
# - Would have made it better.
# - Would have made it worse.✅

# %% [markdown]
# # Machine Learning algorithm
#
# -  Supervised learning
#    -  used most in real-world applications
#    -  rapid advancements
#    -  Reinforcement learning: Another type of supervised learning
# -  Unsupervised learning
#
# Practical advice for applying learning algorithms

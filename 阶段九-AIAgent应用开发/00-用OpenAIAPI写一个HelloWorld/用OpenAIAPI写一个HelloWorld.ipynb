# %% [markdown]
# 1. 使用Open AI国内代理————DevAGI
#
# 2. 获取key后在`.env`文件里设置环境变量
#
# ```bash
# OPENAI_API_KEY="你的key"
# ```
#
# 3. 安装Open—AI相关库
# ```bash
# pip install python-dotenv openai
# ```
#
# 4. 新建`Open—AI_test.py`文件
# 根据DevAGI手册：https://docs.devcto.com/models/openai
# 来调用模型
#
# ```Python
# from openai import OpenAI
# import os
#
# from dotenv import load_dotenv, find_dotenv
# _ = load_dotenv(find_dotenv())
#
# client = OpenAI(
#     api_key=os.getenv("OPENAI_API_KEY"),
#     base_url="https://api.fe8.cn/v1"
# )
#
# response = client.chat.completions.create(
#     messages=[
#         {
#             "role": "user",
#             "content": "讲个笑话",
#         }
#     ],
#     model="gpt-3.5-turbo",
# )
#
# print(response.choices[0].message.content)
# ```
#
# 5. 输出结果
# ```bash
# 当然可以！这是一个简单的笑话：
#
# 有一天，小明去买水果，问老板：“这苹果怎么卖的？”
# 老板说：“十块钱一斤。”
# 小明又问：“那梨呢？”
# 老板说：“十五块钱一斤。”
# 小明想了想，说：“那给我来一斤‘苹梨’，便宜点！”
#
# 希望你喜欢！想听更多笑话吗？
# ```

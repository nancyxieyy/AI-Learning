# %% [markdown]
# ### 1. 感知机

# %% [markdown]
# 从图形上来看，是个二分类的问题
# $$O = \sigma(<W, X> + b) \sigma(x)= 1 if x > 0 or -1$$
# 等价于使用批量大小为1的梯度下降，并使用如下的损失函数
# $$l(y, x, w)=max(0, -y<w,x>)$$
# - 不能你和XOR函数

# %% [markdown]
# ### 2. 多层感知机
